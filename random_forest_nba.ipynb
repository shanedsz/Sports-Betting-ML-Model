# %% [markdown]
# # This will run a Random Forest model on NBA data to predict winners of NBA games

# %%
# Initial Imports
import pandas as pd
from pathlib import Path
from sklearn.ensemble import RandomForestClassifier
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, accuracy_score, classification_report

# %%
nba_df = pd.read_csv(Path('Resources/games.csv'),
                    parse_dates = ['GAME_DATE_EST'], 
                    infer_datetime_format= True)  
nba_df.dropna(inplace = True)
nba_df
# Out:
#       GAME_DATE_EST   GAME_ID GAME_STATUS_TEXT  HOME_TEAM_ID  VISITOR_TEAM_ID  \
# 0        2022-03-12  22101005            Final    1610612748       1610612750
# 1        2022-03-12  22101006            Final    1610612741       1610612739
# 2        2022-03-12  22101007            Final    1610612759       1610612754
# 3        2022-03-12  22101008            Final    1610612744       1610612749
# 4        2022-03-12  22101009            Final    1610612743       1610612761
# ...             ...       ...              ...           ...              ...
# 25791    2014-10-06  11400007            Final    1610612737       1610612740
# 25792    2014-10-06  11400004            Final    1610612741       1610612764
# 25793    2014-10-06  11400005            Final    1610612747       1610612743
# 25794    2014-10-05  11400002            Final    1610612761       1610612758
# 25795    2014-10-04  11400001            Final    1610612748       1610612740
#
#        SEASON  TEAM_ID_home  PTS_home  FG_PCT_home  FT_PCT_home  ...  \
# 0        2021    1610612748     104.0        0.398        0.760  ...
# 1        2021    1610612741     101.0        0.443        0.933  ...
# 2        2021    1610612759     108.0        0.412        0.813  ...
# 3        2021    1610612744     122.0        0.484        0.933  ...
# 4        2021    1610612743     115.0        0.551        0.750  ...
# ...       ...           ...       ...          ...          ...  ...
# 25791    2014    1610612737      93.0        0.419        0.821  ...
# 25792    2014    1610612741      81.0        0.338        0.719  ...
# 25793    2014    1610612747      98.0        0.448        0.682  ...
# 25794    2014    1610612761      99.0        0.440        0.771  ...
# 25795    2014    1610612748      86.0        0.431        0.679  ...
#
#        AST_home  REB_home  TEAM_ID_away  PTS_away  FG_PCT_away  FT_PCT_away  \
# 0          23.0      53.0    1610612750     113.0        0.422        0.875
# 1          20.0      46.0    1610612739      91.0        0.419        0.824
# 2          28.0      52.0    1610612754     119.0        0.489        1.000
# 3          33.0      55.0    1610612749     109.0        0.413        0.696
# 4          32.0      39.0    1610612761     127.0        0.471        0.760
# ...         ...       ...           ...       ...          ...          ...
# 25791      24.0      50.0    1610612740      87.0        0.366        0.643
# 25792      18.0      40.0    1610612764      85.0        0.411        0.636
# 25793      29.0      45.0    1610612743      95.0        0.387        0.659
# 25794      21.0      30.0    1610612758      94.0        0.469        0.725
# 25795      18.0      42.0    1610612740      98.0        0.462        0.706
#
#        FG3_PCT_away  AST_away  REB_away  HOME_TEAM_WINS
# 0             0.357      21.0      46.0               0
# 1             0.208      19.0      40.0               1
# 2             0.389      23.0      47.0               0
# 3             0.386      27.0      39.0               1
# 4             0.387      28.0      50.0               0
# ...             ...       ...       ...             ...
# 25791         0.375      17.0      43.0               1
# 25792         0.267      17.0      47.0               0
# 25793         0.500      19.0      43.0               1
# 25794         0.385      18.0      45.0               1
# 25795         0.438      19.0      42.0               0
#
# [25697 rows x 21 columns]

# %%
nba_df.drop(columns = ['GAME_STATUS_TEXT'], inplace = True)
nba_df['GAME_DATE_EST'] = nba_df['GAME_DATE_EST'].apply(lambda x: x.toordinal())
display(nba_df.dtypes)
display(nba_df)
# Out:
# GAME_DATE_EST        int64
# GAME_ID              int64
# HOME_TEAM_ID         int64
# VISITOR_TEAM_ID      int64
# SEASON               int64
# TEAM_ID_home         int64
# PTS_home           float64
# FG_PCT_home        float64
# FT_PCT_home        float64
# FG3_PCT_home       float64
# AST_home           float64
# REB_home           float64
# TEAM_ID_away         int64
# PTS_away           float64
# FG_PCT_away        float64
# FT_PCT_away        float64
# FG3_PCT_away       float64
# AST_away           float64
# REB_away           float64
# HOME_TEAM_WINS       int64
# dtype: object
#        GAME_DATE_EST   GAME_ID  HOME_TEAM_ID  VISITOR_TEAM_ID  SEASON  \
# 0             738226  22101005    1610612748       1610612750    2021
# 1             738226  22101006    1610612741       1610612739    2021
# 2             738226  22101007    1610612759       1610612754    2021
# 3             738226  22101008    1610612744       1610612749    2021
# 4             738226  22101009    1610612743       1610612761    2021
# ...              ...       ...           ...              ...     ...
# 25791         735512  11400007    1610612737       1610612740    2014
# 25792         735512  11400004    1610612741       1610612764    2014
# 25793         735512  11400005    1610612747       1610612743    2014
# 25794         735511  11400002    1610612761       1610612758    2014
# 25795         735510  11400001    1610612748       1610612740    2014
#
#        TEAM_ID_home  PTS_home  FG_PCT_home  FT_PCT_home  FG3_PCT_home  \
# 0        1610612748     104.0        0.398        0.760         0.333
# 1        1610612741     101.0        0.443        0.933         0.429
# 2        1610612759     108.0        0.412        0.813         0.324
# 3        1610612744     122.0        0.484        0.933         0.400
# 4        1610612743     115.0        0.551        0.750         0.407
# ...             ...       ...          ...          ...           ...
# 25791    1610612737      93.0        0.419        0.821         0.421
# 25792    1610612741      81.0        0.338        0.719         0.381
# 25793    1610612747      98.0        0.448        0.682         0.500
# 25794    1610612761      99.0        0.440        0.771         0.333
# 25795    1610612748      86.0        0.431        0.679         0.333
#
#        AST_home  REB_home  TEAM_ID_away  PTS_away  FG_PCT_away  FT_PCT_away  \
# 0          23.0      53.0    1610612750     113.0        0.422        0.875
# 1          20.0      46.0    1610612739      91.0        0.419        0.824
# 2          28.0      52.0    1610612754     119.0        0.489        1.000
# 3          33.0      55.0    1610612749     109.0        0.413        0.696
# 4          32.0      39.0    1610612761     127.0        0.471        0.760
# ...         ...       ...           ...       ...          ...          ...
# 25791      24.0      50.0    1610612740      87.0        0.366        0.643
# 25792      18.0      40.0    1610612764      85.0        0.411        0.636
# 25793      29.0      45.0    1610612743      95.0        0.387        0.659
# 25794      21.0      30.0    1610612758      94.0        0.469        0.725
# 25795      18.0      42.0    1610612740      98.0        0.462        0.706
#
#        FG3_PCT_away  AST_away  REB_away  HOME_TEAM_WINS
# 0             0.357      21.0      46.0               0
# 1             0.208      19.0      40.0               1
# 2             0.389      23.0      47.0               0
# 3             0.386      27.0      39.0               1
# 4             0.387      28.0      50.0               0
# ...             ...       ...       ...             ...
# 25791         0.375      17.0      43.0               1
# 25792         0.267      17.0      47.0               0
# 25793         0.500      19.0      43.0               1
# 25794         0.385      18.0      45.0               1
# 25795         0.438      19.0      42.0               0
#
# [25697 rows x 20 columns]

# %%
y = nba_df[['HOME_TEAM_WINS']]
X = nba_df.drop(columns = ['HOME_TEAM_WINS'])
display(y.head())
display(X.head())
# Out:
#    HOME_TEAM_WINS
# 0               0
# 1               1
# 2               0
# 3               1
# 4               0
#    GAME_DATE_EST   GAME_ID  HOME_TEAM_ID  VISITOR_TEAM_ID  SEASON  \
# 0         738226  22101005    1610612748       1610612750    2021
# 1         738226  22101006    1610612741       1610612739    2021
# 2         738226  22101007    1610612759       1610612754    2021
# 3         738226  22101008    1610612744       1610612749    2021
# 4         738226  22101009    1610612743       1610612761    2021
#
#    TEAM_ID_home  PTS_home  FG_PCT_home  FT_PCT_home  FG3_PCT_home  AST_home  \
# 0    1610612748     104.0        0.398        0.760         0.333      23.0
# 1    1610612741     101.0        0.443        0.933         0.429      20.0
# 2    1610612759     108.0        0.412        0.813         0.324      28.0
# 3    1610612744     122.0        0.484        0.933         0.400      33.0
# 4    1610612743     115.0        0.551        0.750         0.407      32.0
#
#    REB_home  TEAM_ID_away  PTS_away  FG_PCT_away  FT_PCT_away  FG3_PCT_away  \
# 0      53.0    1610612750     113.0        0.422        0.875         0.357
# 1      46.0    1610612739      91.0        0.419        0.824         0.208
# 2      52.0    1610612754     119.0        0.489        1.000         0.389
# 3      55.0    1610612749     109.0        0.413        0.696         0.386
# 4      39.0    1610612761     127.0        0.471        0.760         0.387
#
#    AST_away  REB_away
# 0      21.0      46.0
# 1      19.0      40.0
# 2      23.0      47.0
# 3      27.0      39.0
# 4      28.0      50.0

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1)

# %%
scaler = MinMaxScaler()
scaler.fit(X_train)
X_train = scaler.transform(X_train)
X_test = scaler.fit_transform(X_test)

# %%
rf_model = RandomForestClassifier()

# %%
rf_model.fit(X_train, y_train)
# Out:
# /Users/Shane/opt/anaconda3/envs/alpacaenv/lib/python3.7/site-packages/ipykernel_launcher.py:1: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   """Entry point for launching an IPython kernel.
# RandomForestClassifier()

# %%
predictions = rf_model.predict(X_test)

# %%
accuracy_score(y_test, predictions)
# Out:
# 0.9587548638132296

# %%
confusion_matrix(y_test, predictions)
# Out:
# array([[2603,   70],
#        [ 195, 3557]])

# %%
classification_report(y_test, predictions)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/yx/41kdsm3n43qcxqf8lcscpt600000gp/T/ipykernel_48350/1352308022.py in <module>
# ----> 1 classification_report(y_test, predictions)
#
# TypeError: 'str' object is not callable

# %%
importances = rf_model.feature_importances_
sorted(zip(rf_model.feature_importances_, X.columns), reverse=True)
# Out:
# [(0.2347595792978125, 'PTS_home'),
#  (0.22202732411498943, 'PTS_away'),
#  (0.11761946508373806, 'FG_PCT_home'),
#  (0.11682583778870483, 'FG_PCT_away'),
#  (0.04034463233992817, 'FG3_PCT_home'),
#  (0.03428955728313377, 'FG3_PCT_away'),
#  (0.031087689778816464, 'REB_away'),
#  (0.030547290411089615, 'AST_home'),
#  (0.029788296322294985, 'REB_home'),
#  (0.027103528103187224, 'AST_away'),
#  (0.018449290699547233, 'FT_PCT_home'),
#  (0.016587800026767806, 'FT_PCT_away'),
#  (0.015418591382851085, 'GAME_DATE_EST'),
#  (0.014575388361216229, 'GAME_ID'),
#  (0.010405108663719333, 'HOME_TEAM_ID'),
#  (0.010223383332201685, 'VISITOR_TEAM_ID'),
#  (0.010117686148791596, 'TEAM_ID_home'),
#  (0.010067211116590037, 'TEAM_ID_away'),
#  (0.009762339744619935, 'SEASON')]
